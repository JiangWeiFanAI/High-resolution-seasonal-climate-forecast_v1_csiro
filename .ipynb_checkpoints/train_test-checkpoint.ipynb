# %%
#for debuging on my computer
import os
import data_processing_tool as dpt
from datetime import timedelta, date, datetime
from args_parameter import args
from PrepareData import ACCESS_BARRA_v1,ACCESS_BARRA_v2

import torch,os,torchvision
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader,random_split
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim

# from PIL import Image
import time
import model
import utility
from tqdm import tqdm
import math
import xarray as xr
from skimage.measure import compare_ssim
from skimage.measure import compare_psnr,compare_mse
import platform 
sys = platform.system()
if sys == "Windows":
    args.file_ACCESS_dir="H:/climate/access-s1/"
    args.file_BARRA_dir="D:/dataset/accum_prcp/"
else:
    args.file_ACCESS_dir_pr="/g/data/ub7/access-s1/hc/raw_model/atmos/pr/daily/"
    args.file_ACCESS_dir="/g/data/ub7/access-s1/hc/raw_model/atmos/"
    # training_name="temp01"
    args.file_BARRA_dir="/g/data/ma05/BARRA_R/v1/forecast/spec/accum_prcp/"

args.n_threads=2
args.channels=1
args.batch_size=4

# ensemble=['e01','e02']
args.ensemble=2
access_rgb_mean= 2.9067910245780248e-05*86400

leading_time=217
args.leading_time_we_use=7
# args.lr=0.001

init_date=date(1970, 1, 1)
start_date=date(1990, 1, 2)
end_date=date(1990,12,25) #if 929 is true we should substract 1 day

print(access_rgb_mean)

print("training statistics:")
print("  ------------------------------")
print("  trainning name  |  %s"%args.train_name)
print("  ------------------------------")
print("  num of channels | %5d"%args.channels)
print("  ------------------------------")
print("  num of threads  | %5d"%args.n_threads)
print("  ------------------------------")
print("  batch_size      | %5d"%args.batch_size)
# Out:
# usage: ipykernel_launcher.py [-h] [--args_test ARGS_TEST] [--debug]
#                              [--template TEMPLATE] [--n_threads N_THREADS]
#                              [--cpu] [--n_GPUs N_GPUS] [--seed SEED] [--pr PR]
#                              [--dem DEM] [--psl PSL] [--zg ZG]
#                              [--tasmax TASMAX] [--tasmin TASMIN]
#                              [--leading_time_we_use LEADING_TIME_WE_USE]
#                              [--ensemble ENSEMBLE] [--channels CHANNELS]
#                              [--domain DOMAIN]
#                              [--file_ACCESS_dir FILE_ACCESS_DIR]
#                              [--file_BARRA_dir FILE_BARRA_DIR]
#                              [--file_DEM_dir FILE_DEM_DIR]
#                              [--nine2nine NINE2NINE]
#                              [--date_minus_one DATE_MINUS_ONE]
#                              [--dir_demo DIR_DEMO] [--benchmark_noise]
#                              [--n_train N_TRAIN] [--n_val N_VAL]
#                              [--offset_val OFFSET_VAL] [--ext EXT]
#                              [--scale SCALE] [--patch_size PATCH_SIZE]
#                              [--rgb_range RGB_RANGE] [--n_colors N_COLORS]
#                              [--noise NOISE] [--chop] [--model MODEL]
#                              [--act ACT] [--pre_train PRE_TRAIN]
#                              [--extend EXTEND] [--n_resblocks N_RESBLOCKS]
#                              [--n_feats N_FEATS] [--res_scale RES_SCALE]
#                              [--shift_mean SHIFT_MEAN]
#                              [--precision {single,half}]
#                              [--train_name TRAIN_NAME] [--reset]
#                              [--test_every TEST_EVERY] [--epochs EPOCHS]
#                              [--batch_size BATCH_SIZE]
#                              [--split_batch SPLIT_BATCH] [--self_ensemble]
#                              [--test_only] [--gan_k GAN_K] [--lr LR]
#                              [--lr_decay LR_DECAY] [--decay_type DECAY_TYPE]
#                              [--gamma GAMMA] [--optimizer {SGD,ADAM,RMSprop}]
#                              [--momentum MOMENTUM] [--beta1 BETA1]
#                              [--beta2 BETA2] [--epsilon EPSILON]
#                              [--weight_decay WEIGHT_DECAY] [--loss LOSS]
#                              [--skip_threshold SKIP_THRESHOLD] [--save SAVE]
#                              [--load LOAD] [--resume RESUME] [--print_model]
#                              [--save_models] [--print_every PRINT_EVERY]
#                              [--save_results] [--n_resgroups N_RESGROUPS]
#                              [--reduction REDUCTION] [--testpath TESTPATH]
#                              [--testset TESTSET] [--degradation DEGRADATION]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\jia059\AppData\Roaming\jupyter\runtime\kernel-173959db-486c-4460-9c26-e3a229af5bd7.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
train_transforms = transforms.Compose([
#     transforms.Resize(IMG_SIZE),
#     transforms.RandomResizedCrop(IMG_SIZE),
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomRotation(30),
    transforms.ToTensor()
#     transforms.Normalize(IMG_MEAN, IMG_STD)
])

data_set=ACCESS_BARRA_v2(start_date,end_date,transform=train_transforms,args=args)
train_data,val_data=random_split(data_set,[int(len(data_set)*0.8),len(data_set)-int(len(data_set)*0.8)])


print("Dataset statistics:")
print("  ------------------------------")
print("  total | %5d"%len(data_set))
print("  ------------------------------")
print("  train | %5d"%len(train_data))
print("  ------------------------------")
print("  val   | %5d"%len(val_data))
data_set[0]
# Out:
# => BARRA_R & ACCESS_S1 loading
# => from 1990/01/02 to 1990/12/25
# D:/dataset/accum_prcp/
# no file or no permission!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Dataset statistics:
#   ------------------------------
#   total |   603
#   ------------------------------
#   train |   482
#   ------------------------------
#   val   |   121
# end loading one data,time cost 5.694444
# (tensor([[[ 1.1128,  1.0071,  0.8324,  ...,  0.1177,  0.0940,  0.0792],
#           [ 0.8782,  0.7939,  0.6557,  ...,  0.1310,  0.0975,  0.0766],
#           [ 0.6086,  0.5499,  0.4534,  ...,  0.1308,  0.0847,  0.0559],
#           ...,
#           [12.3125, 10.7301,  8.1469,  ...,  0.9039,  0.7837,  0.6965],
#           [10.5689,  9.5921,  7.9956,  ...,  0.8609,  0.7071,  0.6023],
#           [ 7.6492,  6.9652,  5.8318,  ...,  0.2447,  0.3304,  0.3709]]],
#         dtype=torch.float64),
#  tensor([[[0.3400, 0.3460, 0.3358,  ..., 0.1293, 0.0962, 0.0825],
#           [0.4064, 0.2850, 0.3204,  ..., 0.1218, 0.1093, 0.1045],
#           [0.2321, 0.2146, 0.2251,  ..., 0.1119, 0.1079, 0.1017],
#           ...,
#           [7.0931, 6.5558, 6.8247,  ..., 0.8953, 0.5499, 0.9100],
#           [5.0458, 5.3771, 5.6308,  ..., 1.0518, 0.7295, 1.1236],
#           [4.7703, 5.1089, 5.6233,  ..., 0.9009, 1.0760, 1.0763]]],
#         dtype=torch.float64),
#  tensor(19900110),
#  tensor(1))

# %%
print(args,)

# %%
##set a the dataLoader
train_dataloders =DataLoader(train_data,
                                        batch_size=args.batch_size,
                                        shuffle=False,
                            num_workers=args.n_threads)
val_dataloders =DataLoader(val_data,
                                        batch_size=args.batch_size,
                                        shuffle=False,
                          num_workers=args.n_threads)
##

# args.cpu=False
def prepare( l, volatile=False):
    device = torch.device('cpu' if args.cpu else 'cuda')
    def _prepare(tensor):
        if args.precision == 'half': tensor = tensor.half()
        return tensor.to(device)

    return [_prepare(_l) for _l in l]

checkpoint = utility.checkpoint(args)
net = model.Model(args, checkpoint).double()
args.lr=0.001
criterion = nn.L1Loss()
optimizer_my = optim.SGD(net.parameters(), lr=args.lr, momentum=0.9)
# scheduler = optim.lr_scheduler.StepLR(optimizer_my, step_size=7, gamma=0.1)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer_my, gamma=0.9)
# torch.optim.lr_scheduler.MultiStepLR(optimizer_my, milestones=[20,80], gamma=0.1)
# Out:
# Making model...
# accesss-s1 mean (0.4690)

# %%
#training
max_error=np.inf
# train_loss=
# print("batch size %d"%args.batch_size)
# print("batch size %d"%args.batch_size)

for e in range(args.epochs):
    #train
    print("start Training for %d"%e)
#     net.train()
    loss=0
    start=time.time()
    print("start Training for start loading data")

    for batch, (lr, hr,_,_) in enumerate(train_dataloders):
        print("start first batch train")
        if not os.path.exists("./model/save/"+args.train_name+"/"):
            os.mkdir("./model/save/"+args.train_name+"/")
        f = open("./model/save/"+args.train_name+"/"+str(batch)+".txt",'w')
        f.close()
        lr, hr = prepare([lr, hr])
#         optimizer_my.zero_grad()
#         with torch.set_grad_enabled(True):
#             sr = net(lr, 0)
# #         error = criterion(sr[:,:,:,0:403], hr)
#             running_loss =criterion(sr, hr)
#             loss+=running_loss 
#         running_loss.backward()
#         optimizer_my.step()
        print("end first batch train")

        
    #validation
    net.eval()
    start=time.time()
    with torch.no_grad():
        eval_psnr=0
        eval_ssim=0
#         tqdm_val = tqdm(val_dataloders, ncols=80)
        for idx_img, (lr, hr,date,_) in enumerate(val_dataloders):
            print("start first batch validation")

            lr, hr = prepare([lr, hr])
#             sr = net(lr, 0)
#             val_loss=criterion(sr, hr)
#             for ssr,hhr in zip(sr,hr):
#                 eval_psnr+=compare_psnr(ssr[0].cpu().numpy(),hhr[0].cpu().numpy(),data_range=(hhr[0].cpu().max()-hhr[0].cpu().min()).item() )
#                 eval_ssim+=compare_ssim(ssr[0].cpu().numpy(),hhr[0].cpu().numpy(),data_range=(hhr[0].cpu().max()-hhr[0].cpu().min()).item() ) 
            print("end first batch validation")

    print("epoche: %d,time cost %f s, lr: %f, train_loss: %f,validation loss:%f "%(
              e,
              time.time()-start,
              optimizer_my.state_dict()['param_groups'][0]['lr'],
              running_loss.item()/len(train_data),
              val_loss
         ))
        
    if running_loss<max_error:
        print("saving")
        max_error=running_loss
        if not os.path.exists("./model/save/"+args.train_name+"/"):
            os.mkdir("./model/save/"+args.train_name+"/")
        f = open("./model/save/"+args.train_name+"/"+str(e)+".txt",'w')
        f.close()
#         torch.save(net,"./model/save/"+args.train_name+"/"+str(e)+".pkl")
        print("end Training for %d"%e)
# Out:
# start Training for 0
# start Training for start loading data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-396fc14abf72> in <module>
#      13     print("start Training for start loading data")
#      14
# ---> 15     for batch, (lr, hr,_,_) in enumerate(train_dataloders):
#      16         print("start first batch train")
#      17
#
# E:\Users\Weifa\Anaconda3\envs\pytorch\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# E:\Users\Weifa\Anaconda3\envs\pytorch\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     839
#     840             assert not self._shutdown and self._tasks_outstanding > 0
# --> 841             idx, data = self._get_data()
#     842             self._tasks_outstanding -= 1
#     843
#
# E:\Users\Weifa\Anaconda3\envs\pytorch\lib\site-packages\torch\utils\data\dataloader.py in _get_data(self)
#     806         else:
#     807             while True:
# --> 808                 success, data = self._try_get_data()
#     809                 if success:
#     810                     return data
#
# E:\Users\Weifa\Anaconda3\envs\pytorch\lib\site-packages\torch\utils\data\dataloader.py in _try_get_data(self, timeout)
#     759         #   (bool: whether successfully get data, any: data if successful else None)
#     760         try:
# --> 761             data = self._data_queue.get(timeout=timeout)
#     762             return (True, data)
#     763         except Exception as e:
#
# E:\Users\Weifa\Anaconda3\envs\pytorch\lib\multiprocessing\queues.py in get(self, block, timeout)
#     105                 if block:
#     106                     timeout = deadline - time.monotonic()
# --> 107                     if not self._poll(timeout):
#     108                         raise Empty
#     109                 elif not self._poll():
#
# E:\Users\Weifa\Anaconda3\envs\pytorch\lib\multiprocessing\connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# E:\Users\Weifa\Anaconda3\envs\pytorch\lib\multiprocessing\connection.py in _poll(self, timeout)
#     328                         _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     329                 return True
# --> 330             return bool(wait([self], timeout))
#     331
#     332         def _get_more_data(self, ov, maxsize):
#
# E:\Users\Weifa\Anaconda3\envs\pytorch\lib\multiprocessing\connection.py in wait(object_list, timeout)
#     876                         timeout = 0
#     877
# --> 878             ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     879         finally:
#     880             # request that overlapped reads stop
#
# E:\Users\Weifa\Anaconda3\envs\pytorch\lib\multiprocessing\connection.py in _exhaustive_wait(handles, timeout)
#     808         ready = []
#     809         while L:
# --> 810             res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     811             if res == WAIT_TIMEOUT:
#     812                 break
#
# KeyboardInterrupt:

# %%
if not os.path.exists("./model/save/"+"teamp1"+"/"):
    os.mkdir("./model/save/"+"teamp1"+"/")
f = open("./model/save/"+"teamp1"+"/"+str(1)+".txt",'w')
f.close()
